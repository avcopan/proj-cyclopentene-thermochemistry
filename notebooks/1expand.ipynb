# %%
from pathlib import Path
import polars as pl

import automech

rmg_path = Path("../data/rmg")

# %%
spc_df0 = pl.read_json("0rename.json")

# %%
spc_df = automech.species.expand_stereo(spc_df0)
# Out:
# ...
#   0%|          | 0/1243 [00:00<?, ?it/s]

# %%
spc_df.write_json("1expand.json")
